# %% [markdown]
# # Leaf Disease Detection

# %%
# !pip install numpy pandas tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow
import os

import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array,load_img
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
os.listdir('data/dataset/')
# Out:
# ['train', 'val']

# %%
train_datagen = ImageDataGenerator(zoom_range=0.5,shear_range=0.3,horizontal_flip=True,preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train = train_datagen.flow_from_directory('data/dataset/train',
                                          target_size=(256,256),
                                          batch_size=32)

val = train_datagen.flow_from_directory('data/dataset/val',
                                          target_size=(256,256),
                                          batch_size=32)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
t_img,label = train.next()

# %%
t_img.shape
# Out:
# (32, 256, 256, 3)

# %%
def plotimg(imgarr,label):
    for im,l in zip(imgarr,label):
        plt.figure(figsize=(5,5))
        plt.imshow(im)
    plt.show()

plotimg(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Model

# %%
base_model = VGG19(input_shape=(256,256,3),include_top=False)

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
X = Flatten()(base_model.output)

X = Dense(units=38,activation='softmax')(X)

model = Model(base_model.input,X)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 38)                1245222
#
# =================================================================
# Total params: 21,269,606
# Trainable params: 1,245,222
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=tensorflow.keras.losses.categorical_crossentropy,metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

es = EarlyStopping(monitor='val_accuracy',min_delta=0.01,patience=3,verbose=1)

mc = ModelCheckpoint(filepath='best_model.h5',
                    monitor = 'val_accuracy',
                    min_delta = 0.01,
                    patience = 3,
                    verbose = 1,
                    save_best_only = True)

cb = [es,mc]

# %%
his = model.fit(train, 
                steps_per_epoch=16,
                epochs=50,
                verbose=1,
                callbacks=cb,
                validation_data=val,
                validation_steps=16)
# Out:
# Epoch 1/50
# 16/16 [==============================] - ETA: 0s - loss: 29.4476 - accuracy: 0.1504
# Epoch 1: val_accuracy improved from -inf to 0.31445, saving model to best_model.h5
# 16/16 [==============================] - 99s 2s/step - loss: 29.4476 - accuracy: 0.1504 - val_loss: 18.6184 - val_accuracy: 0.3145
# Epoch 2/50
# 16/16 [==============================] - ETA: 0s - loss: 15.6275 - accuracy: 0.4004
# Epoch 2: val_accuracy improved from 0.31445 to 0.49609, saving model to best_model.h5
# 16/16 [==============================] - 31s 2s/step - loss: 15.6275 - accuracy: 0.4004 - val_loss: 13.1549 - val_accuracy: 0.4961
# Epoch 3/50
# 16/16 [==============================] - ETA: 0s - loss: 10.7396 - accuracy: 0.5508
# Epoch 3: val_accuracy improved from 0.49609 to 0.58398, saving model to best_model.h5
# 16/16 [==============================] - 32s 2s/step - loss: 10.7396 - accuracy: 0.5508 - val_loss: 9.8379 - val_accuracy: 0.5840
# Epoch 4/50
# 16/16 [==============================] - ETA: 0s - loss: 8.0665 - accuracy: 0.6250
# Epoch 4: val_accuracy improved from 0.58398 to 0.59961, saving model to best_model.h5
# 16/16 [==============================] - 31s 2s/step - loss: 8.0665 - accuracy: 0.6250 - val_loss: 9.6946 - val_accuracy: 0.5996
# Epoch 5/50
# 16/16 [==============================] - ETA: 0s - loss: 8.8581 - accuracy: 0.6055
# Epoch 5: val_accuracy improved from 0.59961 to 0.61133, saving model to best_model.h5
# 16/16 [==============================] - 31s 2s/step - loss: 8.8581 - accuracy: 0.6055 - val_loss: 9.1813 - val_accuracy: 0.6113
# Epoch 6/50
# 16/16 [==============================] - ETA: 0s - loss: 9.4114 - accuracy: 0.6680
# Epoch 6: val_accuracy improved from 0.61133 to 0.68359, saving model to best_model.h5
# 16/16 [==============================] - 31s 2s/step - loss: 9.4114 - accuracy: 0.6680 - val_loss: 9.0753 - val_accuracy: 0.6836
# Epoch 7/50
# 16/16 [==============================] - ETA: 0s - loss: 7.9224 - accuracy: 0.6621
# Epoch 7: val_accuracy did not improve from 0.68359
# 16/16 [==============================] - 30s 2s/step - loss: 7.9224 - accuracy: 0.6621 - val_loss: 8.6130 - val_accuracy: 0.6738
# Epoch 8/50
# 16/16 [==============================] - ETA: 0s - loss: 7.3117 - accuracy: 0.7109
# Epoch 8: val_accuracy did not improve from 0.68359
# 16/16 [==============================] - 32s 2s/step - loss: 7.3117 - accuracy: 0.7109 - val_loss: 8.8695 - val_accuracy: 0.6543
# Epoch 9/50
# 16/16 [==============================] - ETA: 0s - loss: 9.2329 - accuracy: 0.6699
# Epoch 9: val_accuracy did not improve from 0.68359
# 16/16 [==============================] - 32s 2s/step - loss: 9.2329 - accuracy: 0.6699 - val_loss: 9.6422 - val_accuracy: 0.6562
# Epoch 9: early stopping

# %%
h = his.history

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'],c='red')
plt.title('acc vs val_acc')
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'],c='red')
plt.title('loss vs val_loss')
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('best_model.h5')

# %%
acc = model.evaluate(val)[1]

print(f'The accuracy of our model on val data is {acc*100}')
# Out:
# 550/550 [==============================] - 590s 1s/step - loss: 8.3589 - accuracy: 0.6639
# The accuracy of our model on val data is 66.38970971107483

# %%
ref = dict(zip(list(train.class_indices.values()),list(train.class_indices.keys())))

# %%
def prediction(path):
    img = load_img(path,target_size=(256,256))
    img = img_to_array(img)
    img = preprocess_input(img)
    img = np.expand_dims(img,axis=0)
    pred = np.argmax(model.predict(img))
    return ref[pred]

# %%
for i in os.listdir('data/images_for_test'):
    pred = prediction(f'data/images_for_test/{i}')
    print(f'Actual --> {i}')
    print(f'Predicted --> {pred}')
    plt.show()
# Out:
# 1/1 [==============================] - 4s 4s/step
# Actual --> AppleCedarRust1.JPG
# Predicted --> Apple___Cedar_apple_rust
# 1/1 [==============================] - 0s 47ms/step
# Actual --> AppleCedarRust2.JPG
# Predicted --> Tomato___Septoria_leaf_spot
# 1/1 [==============================] - 0s 36ms/step
# Actual --> AppleCedarRust3.JPG
# Predicted --> Tomato___Septoria_leaf_spot
# 1/1 [==============================] - 0s 32ms/step
# Actual --> AppleCedarRust4.JPG
# Predicted --> Apple___Cedar_apple_rust
# 1/1 [==============================] - 0s 46ms/step
# Actual --> AppleScab1.JPG
# Predicted --> Tomato___Bacterial_spot
# 1/1 [==============================] - 0s 17ms/step
# Actual --> AppleScab2.JPG
# Predicted --> Apple___Apple_scab
# 1/1 [==============================] - 0s 28ms/step
# Actual --> AppleScab3.JPG
# Predicted --> Apple___Apple_scab
# 1/1 [==============================] - 0s 32ms/step
# Actual --> CornCommonRust1.JPG
# Predicted --> Corn_(maize)___Common_rust_
# 1/1 [==============================] - 0s 41ms/step
# Actual --> CornCommonRust2.JPG
# Predicted --> Corn_(maize)___Common_rust_
# 1/1 [==============================] - 0s 40ms/step
# Actual --> CornCommonRust3.JPG
# Predicted --> Corn_(maize)___Common_rust_
# 1/1 [==============================] - 0s 36ms/step
# Actual --> PotatoEarlyBlight1.JPG
# Predicted --> Potato___Early_blight
# 1/1 [==============================] - 0s 36ms/step
# Actual --> PotatoEarlyBlight2.JPG
# Predicted --> Potato___Early_blight
# 1/1 [==============================] - 0s 29ms/step
# Actual --> PotatoEarlyBlight3.JPG
# Predicted --> Potato___Late_blight
# 1/1 [==============================] - 0s 26ms/step
# Actual --> PotatoEarlyBlight4.JPG
# Predicted --> Potato___Early_blight
# 1/1 [==============================] - 0s 36ms/step
# Actual --> PotatoEarlyBlight5.JPG
# Predicted --> Potato___Late_blight
# 1/1 [==============================] - 0s 32ms/step
# Actual --> PotatoHealthy1.JPG
# Predicted --> Potato___Late_blight
# 1/1 [==============================] - 0s 33ms/step
# Actual --> PotatoHealthy2.JPG
# Predicted --> Potato___Late_blight
# 1/1 [==============================] - 0s 36ms/step
# Actual --> TomatoEarlyBlight1.JPG
# Predicted --> Tomato___Early_blight
# 1/1 [==============================] - 0s 33ms/step
# Actual --> TomatoEarlyBlight3.JPG
# Predicted --> Tomato___Septoria_leaf_spot
# 1/1 [==============================] - 0s 30ms/step
# Actual --> TomatoEarlyBlight4.JPG
# Predicted --> Tomato___Septoria_leaf_spot
# 1/1 [==============================] - 0s 46ms/step
# Actual --> TomatoEarlyBlight5.JPG
# Predicted --> Tomato___Target_Spot
# 1/1 [==============================] - 0s 43ms/step
# Actual --> TomatoEarlyBlight6.JPG
# Predicted --> Potato___Late_blight
# 1/1 [==============================] - 0s 35ms/step
# Actual --> TomatoHealthy1.JPG
# Predicted --> Tomato___healthy
# 1/1 [==============================] - 0s 40ms/step
# Actual --> TomatoHealthy2.JPG
# Predicted --> Tomato___Spider_mites Two-spotted_spider_mite
# 1/1 [==============================] - 0s 16ms/step
# Actual --> TomatoHealthy3.JPG
# Predicted --> Tomato___Target_Spot
# 1/1 [==============================] - 0s 35ms/step
# Actual --> TomatoHealthy4.JPG
# Predicted --> Tomato___Target_Spot
# 1/1 [==============================] - 0s 32ms/step
# Actual --> TomatoYellowCurlVirus1.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1/1 [==============================] - 0s 35ms/step
# Actual --> TomatoYellowCurlVirus2.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1/1 [==============================] - 0s 31ms/step
# Actual --> TomatoYellowCurlVirus3.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1/1 [==============================] - 0s 35ms/step
# Actual --> TomatoYellowCurlVirus4.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1/1 [==============================] - 0s 41ms/step
# Actual --> TomatoYellowCurlVirus5.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1/1 [==============================] - 0s 25ms/step
# Actual --> TomatoYellowCurlVirus6.JPG
# Predicted --> Tomato___Tomato_Yellow_Leaf_Curl_Virus
